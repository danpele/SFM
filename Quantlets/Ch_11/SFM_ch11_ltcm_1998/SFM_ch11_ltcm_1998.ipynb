# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_ltcm_1998/SFM_ch11_ltcm_1998.ipynb)

# %% [markdown]
# # SFM_ch11_ltcm_1998

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_ltcm_1998

fig_ltcm_1998()

# %% [markdown]
# ![ch11_ltcm_1998](./ch11_ltcm_1998.png)
#
# Output: `ch11_ltcm_1998.pdf`
