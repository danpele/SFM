# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_method_normal/SFM_ch11_method_normal.ipynb)

# %% [markdown]
# # SFM_ch11_method_normal

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_method_normal

fig_method_normal()

# %% [markdown]
# ![ch11_method_normal](./ch11_method_normal.png)
#
# Output: `ch11_method_normal.pdf`
