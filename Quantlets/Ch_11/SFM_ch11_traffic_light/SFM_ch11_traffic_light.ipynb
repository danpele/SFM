# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_traffic_light/SFM_ch11_traffic_light.ipynb)

# %% [markdown]
# # SFM_ch11_traffic_light

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_traffic_light

fig_traffic_light()

# %% [markdown]
# ![ch11_traffic_light](./ch11_traffic_light.png)
#
# Output: `ch11_traffic_light.pdf`
