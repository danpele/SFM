# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_bvb_case/SFM_ch11_bvb_case.ipynb)

# %% [markdown]
# # SFM_ch11_bvb_case

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_bvb_case

fig_bvb_case()

# %% [markdown]
# ![ch11_bvb_case](./ch11_bvb_case.png)
#
# Output: `ch11_bvb_case.pdf`
