# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_subadditivity/SFM_ch11_subadditivity.ipynb)

# %% [markdown]
# # SFM_ch11_subadditivity

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_subadditivity

fig_subadditivity()

# %% [markdown]
# ![ch11_subadditivity](./ch11_subadditivity.png)
#
# Output: `ch11_subadditivity.pdf`
