# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_lvar/SFM_ch11_lvar.ipynb)

# %% [markdown]
# # SFM_ch11_lvar

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_lvar

fig_lvar()

# %% [markdown]
# ![ch11_lvar](./ch11_lvar.png)
#
# Output: `ch11_lvar.pdf`
