# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_gjr_garch/SFM_ch11_gjr_garch.ipynb)

# %% [markdown]
# # SFM_ch11_gjr_garch

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_gjr_garch

fig_gjr_garch()

# %% [markdown]
# ![ch11_gjr_garch](./ch11_gjr_garch.png)
#
# Output: `ch11_gjr_garch.pdf`
