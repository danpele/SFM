# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_acerbi_szekely/SFM_ch11_acerbi_szekely.ipynb)

# %% [markdown]
# # SFM_ch11_acerbi_szekely

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_acerbi_szekely

fig_acerbi_szekely()

# %% [markdown]
# ![ch11_acerbi_szekely](./ch11_acerbi_szekely.png)
#
# Output: `ch11_acerbi_szekely.pdf`
