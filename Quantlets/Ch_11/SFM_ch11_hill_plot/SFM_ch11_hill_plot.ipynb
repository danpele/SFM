# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_hill_plot/SFM_ch11_hill_plot.ipynb)

# %% [markdown]
# # SFM_ch11_hill_plot

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_hill_plot

fig_hill_plot()

# %% [markdown]
# ![ch11_hill_plot](./ch11_hill_plot.png)
#
# Output: `ch11_hill_plot.pdf`
