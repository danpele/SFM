# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_var_horizons/SFM_ch11_var_horizons.ipynb)

# %% [markdown]
# # SFM_ch11_var_horizons

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_var_horizons

fig_var_horizons()

# %% [markdown]
# ![ch11_var_horizons](./ch11_var_horizons.png)
#
# Output: `ch11_var_horizons.pdf`
