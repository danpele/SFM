# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_es_var_ratio/SFM_ch11_es_var_ratio.ipynb)

# %% [markdown]
# # SFM_ch11_es_var_ratio

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_es_var_ratio

fig_es_var_ratio()

# %% [markdown]
# ![ch11_es_var_ratio](./ch11_es_var_ratio.png)
#
# Output: `ch11_es_var_ratio.pdf`
