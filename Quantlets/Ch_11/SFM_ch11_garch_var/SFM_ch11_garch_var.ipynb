# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_garch_var/SFM_ch11_garch_var.ipynb)

# %% [markdown]
# # SFM_ch11_garch_var

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_garch_var

fig_garch_var()

# %% [markdown]
# ![ch11_garch_var](./ch11_garch_var.png)
#
# Output: `ch11_garch_var.pdf`
