# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_rolling_var_es/SFM_ch11_rolling_var_es.ipynb)

# %% [markdown]
# # SFM_ch11_rolling_var_es

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_rolling_var_es

fig_rolling_var_es()

# %% [markdown]
# ![ch11_rolling_var_es](./ch11_rolling_var_es.png)
#
# Output: `ch11_rolling_var_es.pdf`
