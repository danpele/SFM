# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_cross_asset/SFM_ch11_cross_asset.ipynb)

# %% [markdown]
# # SFM_ch11_cross_asset

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_cross_asset

fig_cross_asset()

# %% [markdown]
# ![ch11_cross_asset](./ch11_cross_asset.png)
#
# Output: `ch11_cross_asset.pdf`
