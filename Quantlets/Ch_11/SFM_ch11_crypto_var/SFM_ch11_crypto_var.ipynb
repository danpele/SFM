# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_crypto_var/SFM_ch11_crypto_var.ipynb)

# %% [markdown]
# # SFM_ch11_crypto_var

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_crypto_var

fig_crypto_var()

# %% [markdown]
# ![ch11_crypto_var](./ch11_crypto_var.png)
#
# Output: `ch11_crypto_var.pdf`
