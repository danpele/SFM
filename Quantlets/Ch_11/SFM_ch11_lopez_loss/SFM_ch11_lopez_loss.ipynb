# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_lopez_loss/SFM_ch11_lopez_loss.ipynb)

# %% [markdown]
# # SFM_ch11_lopez_loss

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_lopez_loss

fig_lopez_loss()

# %% [markdown]
# ![ch11_lopez_loss](./ch11_lopez_loss.png)
#
# Output: `ch11_lopez_loss.pdf`
