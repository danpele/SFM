# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/SFM/blob/main/Quantlets/Ch_11/SFM_ch11_archegos_2021/SFM_ch11_archegos_2021.ipynb)

# %% [markdown]
# # SFM_ch11_archegos_2021

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
from generate_all_charts import fig_archegos_2021

fig_archegos_2021()

# %% [markdown]
# ![ch11_archegos_2021](./ch11_archegos_2021.png)
#
# Output: `ch11_archegos_2021.pdf`
